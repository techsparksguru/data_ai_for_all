# %% [markdown]
# # Python Version on Mac
# - Jupyter lab should start with same python , that is used by Apache Spark
# - For mac, you can do the below (if you are using brew) - All versions go into /usr/local/Cellar directory
#     - brew unlink python@3.9
#     - brew unlink python@3.8
#     - brew link --force python@3.9
# - If jupyterlab somehow picks up 3.9 (though you did above),uninstall jupyterlab and re-install again (FYI. jupyterlab fails to start with 3.7 with traitlets error, then `pip3 install jupyter_server==1.13.1` & `pip3 install jupyter_client==7.1.0` from command line. After this jupyterlab starts fine

# %% [markdown]
# # Start Spark Cluster
# - From `$SPARK_HOME/bin` execute `./sbin/start-all.sh`. More [options](https://spark.apache.org/docs/latest/spark-standalone.html) for passing parameters

# %%
# The whole folder for apache-spark is downloaded to site-packages folder , if you are interested to know 
# https://spark.apache.org/docs/latest/api/python/getting_started/install.html
# !pip3 install pyspark==3.3.0
# !pip3 install openpyxl==3.0.9
# !pip3 install pyspark[pandas_on_spark] - If this errors, just install it from shell command

# %%
# Below variables are to be set in the shell profile
# export SPARK_HOME=/Users/pmacharl/spark-3.3.0-bin-hadoop3
# export PATH=$PATH:$SPARK_HOME/bin
# export PYSPARK_SUBMIT_ARGS="pyspark-shell"
# export PYSPARK_DRIVER_PYTHON=/usr/local/bin/python3
# export PYSPARK_PYTHON=/usr/local/bin/python3
# export PYARROW_IGNORE_TIMEZONE=1

# %%
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf

# %%
# https://spark.apache.org/docs/latest/api/python/pyspark.html#pyspark.SparkConf
config = SparkConf()
config.set("spark.driver.memory", "2g")
config.set("spark.executor.memory", "1g")

# Because you are likely running in local mode, it is a good practice to set the number of shuffle partitions
# to something that is going to fit local mode. By default, the value is 200, but there aren't many executors
# on this machine, its worth reducing this to 5
config.set("spark.sql.shuffle.partitions", "5")

# Cluster mode
# https://spark.apache.org/docs/latest/submitting-applications.html
config.setMaster("spark://192.168.0.109:7077") # DONT SET THIS If spark is started in local cluster mode

# %%
# https://spark.apache.org/docs/latest/api/python/pyspark.sql.html#pyspark.sql.SparkSession
# spark = SparkSession.builder.config(conf=config).master("local").appName("Analyzing Real Estate Sales").getOrCreate()

# Cluster mode
spark = SparkSession.builder.config(conf=config).master("spark://192.168.0.109:7077").appName("Reading Excel").getOrCreate()
# spark = SparkSession.builder.config(conf=config).master("local").appName("Reading Excel").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.0.109:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://192.168.0.109:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Reading Excel</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# # Pandas-on-Spark Api (koalas before) data types conversion between spark dataframe and pandas dataframe
# ```
# tinyint                int8
# decimal              object
# float               float32
# double              float64
# integer               int32
# long                  int64
# short                 int16
# timestamp    datetime64[ns]
# string               object
# boolean                bool
# date                 object
# ```

# %%
# This will piggyback on the existing SparkSession in memory
import pyspark.pandas as ps
df = ps.read_excel("./data/columns.xlsx")
df
# Out:
# /usr/local/lib/python3.7/site-packages/pyspark/pandas/namespace.py:1151: FutureWarning: convert_float is deprecated and will be removed in a future version
#   **kwds,
#           RealEstData04182022.xlsx        RealEstData04192022.xlsx        RealEstData04172022.xlsx        RealEstData04162022.xlsx        RealEstData04152022.xlsx        RealEstData04132022.xlsx        RealEstData04122022.xlsx        RealEstData04142022.xlsx
# 0                           OWNER1                          OWNER1                          OWNER1                          OWNER1                          OWNER1                          OWNER1                          OWNER1                          OWNER1
# 1                           OWNER2                          OWNER2                          OWNER2                          OWNER2                          OWNER2                          OWNER2                          OWNER2                          OWNER2
# 2                 Mailing_address1                Mailing_address1                Mailing_address1                Mailing_address1                Mailing_address1                Mailing_address1                Mailing_address1                Mailing_address1
# 3                 Mailing_Address2                Mailing_Address2                Mailing_Address2                Mailing_Address2                Mailing_Address2                Mailing_Address2                Mailing_Address2                Mailing_Address2
# 4                 Mailing_Address3                Mailing_Address3                Mailing_Address3                Mailing_Address3                Mailing_Address3                Mailing_Address3                Mailing_Address3                Mailing_Address3
# 5                   REAL_ESTATE_ID                  REAL_ESTATE_ID                  REAL_ESTATE_ID                  REAL_ESTATE_ID                  REAL_ESTATE_ID                  REAL_ESTATE_ID                  REAL_ESTATE_ID                  REAL_ESTATE_ID
# 6                      CARD_NUMBER                     CARD_NUMBER                     CARD_NUMBER                     CARD_NUMBER                     CARD_NUMBER                     CARD_NUMBER                     CARD_NUMBER                     CARD_NUMBER
# 7                  NUMBER_OF_CARDS                 NUMBER_OF_CARDS                 NUMBER_OF_CARDS                 NUMBER_OF_CARDS                 NUMBER_OF_CARDS                 NUMBER_OF_CARDS                 NUMBER_OF_CARDS                 NUMBER_OF_CARDS
# 8                    Street_Number                   Street_Number                   Street_Number                   Street_Number                   Street_Number                   Street_Number                   Street_Number                   Street_Number
# 9                    Street_Prefix                   Street_Prefix                   Street_Prefix                   Street_Prefix                   Street_Prefix                   Street_Prefix                   Street_Prefix                   Street_Prefix
# 10                     Street_Name                     Street_Name                     Street_Name                     Street_Name                     Street_Name                     Street_Name                     Street_Name                     Street_Name
# 11                     Street_Type                     Street_Type                     Street_Type                     Street_Type                     Street_Type                     Street_Type                     Street_Type                     Street_Type
# 12                   Street_Suffix                   Street_Suffix                   Street_Suffix                   Street_Suffix                   Street_Suffix                   Street_Suffix                   Street_Suffix                   Street_Suffix
# 13           Planning_Jurisdiction           Planning_Jurisdiction           Planning_Jurisdiction           Planning_Jurisdiction           Planning_Jurisdiction           Planning_Jurisdiction           Planning_Jurisdiction           Planning_Jurisdiction
# 14                     Street_Misc                     Street_Misc                     Street_Misc                     Street_Misc                     Street_Misc                     Street_Misc                     Street_Misc                     Street_Misc
# 15                        Township                        Township                        Township                        Township                        Township                        Township                        Township                        Township
# 16                   Fire_District                   Fire_District                   Fire_District                   Fire_District                   Fire_District                   Fire_District                   Fire_District                   Fire_District
# 17                 Land_Sale_Price                 Land_Sale_Price                 Land_Sale_Price                 Land_Sale_Price                 Land_Sale_Price                 Land_Sale_Price                 Land_Sale_Price                 Land_Sale_Price
# 18                  Land_Sale_Date                  Land_Sale_Date                  Land_Sale_Date                  Land_Sale_Date                  Land_Sale_Date                  Land_Sale_Date                  Land_Sale_Date                  Land_Sale_Date
# 19                          Zoning                          Zoning                          Zoning                          Zoning                          Zoning                          Zoning                          Zoning                          Zoning
# 20                  Deeded_Acreage                  Deeded_Acreage                  Deeded_Acreage                  Deeded_Acreage                  Deeded_Acreage                  Deeded_Acreage                  Deeded_Acreage                  Deeded_Acreage
# 21                Total_sale_Price                Total_sale_Price                Total_sale_Price                Total_sale_Price                Total_sale_Price                Total_sale_Price                Total_sale_Price                Total_sale_Price
# 22                 Total_Sale_Date                 Total_Sale_Date                 Total_Sale_Date                 Total_Sale_Date                 Total_Sale_Date                 Total_Sale_Date                 Total_Sale_Date                 Total_Sale_Date
# 23         Assessed_Building_Value         Assessed_Building_Value         Assessed_Building_Value         Assessed_Building_Value         Assessed_Building_Value         Assessed_Building_Value         Assessed_Building_Value         Assessed_Building_Value
# 24             Assessed_Land_Value             Assessed_Land_Value             Assessed_Land_Value             Assessed_Land_Value             Assessed_Land_Value             Assessed_Land_Value             Assessed_Land_Value             Assessed_Land_Value
# 25           Parcel_Identification           Parcel_Identification           Parcel_Identification           Parcel_Identification           Parcel_Identification           Parcel_Identification           Parcel_Identification           Parcel_Identification
# 26               Special_District1               Special_District1               Special_District1               Special_District1               Special_District1               Special_District1               Special_District1               Special_District1
# 27               Special_District2               Special_District2               Special_District2               Special_District2               Special_District2               Special_District2               Special_District2               Special_District2
# 28               Special_District3               Special_District3               Special_District3               Special_District3               Special_District3               Special_District3               Special_District3               Special_District3
# 29                   BILLING_CLASS                   BILLING_CLASS                   BILLING_CLASS                   BILLING_CLASS                   BILLING_CLASS                   BILLING_CLASS                   BILLING_CLASS                   BILLING_CLASS
# 30            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION            PROPERTY_DESCRIPTION
# 31             Land_classification             Land_classification             Land_classification             Land_classification             Land_classification             Land_classification             Land_classification             Land_classification
# 32                       DEED_BOOK                       DEED_BOOK                       DEED_BOOK                       DEED_BOOK                       DEED_BOOK                       DEED_BOOK                       DEED_BOOK                       DEED_BOOK
# 33                       DEED_PAGE                       DEED_PAGE                       DEED_PAGE                       DEED_PAGE                       DEED_PAGE                       DEED_PAGE                       DEED_PAGE                       DEED_PAGE
# 34                       Deed_Date                       Deed_Date                       Deed_Date                       Deed_Date                       Deed_Date                       Deed_Date                       Deed_Date                       Deed_Date
# 35                             VCS                             VCS                             VCS                             VCS                             VCS                             VCS                             VCS                             VCS
# 36                  PROPERTY_INDEX                  PROPERTY_INDEX                  PROPERTY_INDEX                  PROPERTY_INDEX                  PROPERTY_INDEX                  PROPERTY_INDEX                  PROPERTY_INDEX                  PROPERTY_INDEX
# 37                      Year_Built                      Year_Built                      Year_Built                      Year_Built                      Year_Built                      Year_Built                      Year_Built                      Year_Built
# 38                    NUM_of_Rooms                    NUM_of_Rooms                    NUM_of_Rooms                    NUM_of_Rooms                    NUM_of_Rooms                    NUM_of_Rooms                    NUM_of_Rooms                    NUM_of_Rooms
# 39                           UNITS                           UNITS                           UNITS                           UNITS                           UNITS                           UNITS                           UNITS                           UNITS
# 40                     HEATED_AREA                     HEATED_AREA                     HEATED_AREA                     HEATED_AREA                     HEATED_AREA                     HEATED_AREA                     HEATED_AREA                     HEATED_AREA
# 41                       UTILITIES                       UTILITIES                       UTILITIES                       UTILITIES                       UTILITIES                       UTILITIES                       UTILITIES                       UTILITIES
# 42                 Street_pavement                 Street_pavement                 Street_pavement                 Street_pavement                 Street_pavement                 Street_pavement                 Street_pavement                 Street_pavement
# 43                      TOPOGRAPHY                      TOPOGRAPHY                      TOPOGRAPHY                      TOPOGRAPHY                      TOPOGRAPHY                      TOPOGRAPHY                      TOPOGRAPHY                      TOPOGRAPHY
# 44                Year_of_Addition                Year_of_Addition                Year_of_Addition                Year_of_Addition                Year_of_Addition                Year_of_Addition                Year_of_Addition                Year_of_Addition
# 45                  Effective_year                  Effective_year                  Effective_year                  Effective_year                  Effective_year                  Effective_year                  Effective_year                  Effective_year
# 46                  Remodeled_Year                  Remodeled_Year                  Remodeled_Year                  Remodeled_Year                  Remodeled_Year                  Remodeled_Year                  Remodeled_Year                  Remodeled_Year
# 47                Special_Write_In                Special_Write_In                Special_Write_In                Special_Write_In                Special_Write_In                Special_Write_In                Special_Write_In                Special_Write_In
# 48                    Story_Height                    Story_Height                    Story_Height                    Story_Height                    Story_Height                    Story_Height                    Story_Height                    Story_Height
# 49                    DESIGN_STYLE                    DESIGN_STYLE                    DESIGN_STYLE                    DESIGN_STYLE                    DESIGN_STYLE                    DESIGN_STYLE                    DESIGN_STYLE                    DESIGN_STYLE
# 50             Foundation_Basement             Foundation_Basement             Foundation_Basement             Foundation_Basement             Foundation_Basement             Foundation_Basement             Foundation_Basement             Foundation_Basement
# 51     Foundation_Basement_Percent     Foundation_Basement_Percent     Foundation_Basement_Percent     Foundation_Basement_Percent     Foundation_Basement_Percent     Foundation_Basement_Percent     Foundation_Basement_Percent     Foundation_Basement_Percent
# 52                   Exterior_Wall                   Exterior_Wall                   Exterior_Wall                   Exterior_Wall                   Exterior_Wall                   Exterior_Wall                   Exterior_Wall                   Exterior_Wall
# 53                     COMMON_WALL                     COMMON_WALL                     COMMON_WALL                     COMMON_WALL                     COMMON_WALL                     COMMON_WALL                     COMMON_WALL                     COMMON_WALL
# 54                            ROOF                            ROOF                            ROOF                            ROOF                            ROOF                            ROOF                            ROOF                            ROOF
# 55               Roof_Floor_System               Roof_Floor_System               Roof_Floor_System               Roof_Floor_System               Roof_Floor_System               Roof_Floor_System               Roof_Floor_System               Roof_Floor_System
# 56                    Floor_Finish                    Floor_Finish                    Floor_Finish                    Floor_Finish                    Floor_Finish                    Floor_Finish                    Floor_Finish                    Floor_Finish
# 57                 Interior_Finish                 Interior_Finish                 Interior_Finish                 Interior_Finish                 Interior_Finish                 Interior_Finish                 Interior_Finish                 Interior_Finish
# 58                Interior_Finish1                Interior_Finish1                Interior_Finish1                Interior_Finish1                Interior_Finish1                Interior_Finish1                Interior_Finish1                Interior_Finish1
# 59        Interior_Finish1_percent        Interior_Finish1_percent        Interior_Finish1_percent        Interior_Finish1_percent        Interior_Finish1_percent        Interior_Finish1_percent        Interior_Finish1_percent        Interior_Finish1_percent
# 60                Interior_Finish2                Interior_Finish2                Interior_Finish2                Interior_Finish2                Interior_Finish2                Interior_Finish2                Interior_Finish2                Interior_Finish2
# 61        Interior_Finish2_percent        Interior_Finish2_percent        Interior_Finish2_percent        Interior_Finish2_percent        Interior_Finish2_percent        Interior_Finish2_percent        Interior_Finish2_percent        Interior_Finish2_percent
# 62                            HEAT                            HEAT                            HEAT                            HEAT                            HEAT                            HEAT                            HEAT                            HEAT
# 63                    HEAT_PERCENT                    HEAT_PERCENT                    HEAT_PERCENT                    HEAT_PERCENT                    HEAT_PERCENT                    HEAT_PERCENT                    HEAT_PERCENT                    HEAT_PERCENT
# 64                             AIR                             AIR                             AIR                             AIR                             AIR                             AIR                             AIR                             AIR
# 65                     AIR_PERCENT                     AIR_PERCENT                     AIR_PERCENT                     AIR_PERCENT                     AIR_PERCENT                     AIR_PERCENT                     AIR_PERCENT                     AIR_PERCENT
# 66                            BATH                            BATH                            BATH                            BATH                            BATH                            BATH                            BATH                            BATH
# 67                   BATH_FIXTURES                   BATH_FIXTURES                   BATH_FIXTURES                   BATH_FIXTURES                   BATH_FIXTURES                   BATH_FIXTURES                   BATH_FIXTURES                   BATH_FIXTURES
# 68           Built_in1_Description           Built_in1_Description           Built_in1_Description           Built_in1_Description           Built_in1_Description           Built_in1_Description           Built_in1_Description           Built_in1_Description
# 69           Built_in2_Description           Built_in2_Description           Built_in2_Description           Built_in2_Description           Built_in2_Description           Built_in2_Description           Built_in2_Description           Built_in2_Description
# 70           Built_in3_Description           Built_in3_Description           Built_in3_Description           Built_in3_Description           Built_in3_Description           Built_in3_Description           Built_in3_Description           Built_in3_Description
# 71           Built_in4_Description           Built_in4_Description           Built_in4_Description           Built_in4_Description           Built_in4_Description           Built_in4_Description           Built_in4_Description           Built_in4_Description
# 72           Built_in5_Description           Built_in5_Description           Built_in5_Description           Built_in5_Description           Built_in5_Description           Built_in5_Description           Built_in5_Description           Built_in5_Description
# 73                            CITY                            CITY                            CITY                            CITY                            CITY                            CITY                            CITY                            CITY
# 74                           GRADE                           GRADE                           GRADE                           GRADE                           GRADE                           GRADE                           GRADE                           GRADE
# 75       Assessed_Grade_Difference       Assessed_Grade_Difference       Assessed_Grade_Difference       Assessed_Grade_Difference       Assessed_Grade_Difference       Assessed_Grade_Difference       Assessed_Grade_Difference       Assessed_Grade_Difference
# 76  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct  Accrued_Assessed_Condition_Pct
# 77              Land_Deferred_code              Land_Deferred_code              Land_Deferred_code              Land_Deferred_code              Land_Deferred_code              Land_Deferred_code              Land_Deferred_code              Land_Deferred_code
# 78            Land_Deferred_Amount            Land_Deferred_Amount            Land_Deferred_Amount            Land_Deferred_Amount            Land_Deferred_Amount            Land_Deferred_Amount            Land_Deferred_Amount            Land_Deferred_Amount
# 79          Historic_Deferred_code          Historic_Deferred_code          Historic_Deferred_code          Historic_Deferred_code          Historic_Deferred_code          Historic_Deferred_code          Historic_Deferred_code          Historic_Deferred_code
# 80        Historic_Deferred_Amount        Historic_Deferred_Amount        Historic_Deferred_Amount        Historic_Deferred_Amount        Historic_Deferred_Amount        Historic_Deferred_Amount        Historic_Deferred_Amount        Historic_Deferred_Amount
# 81                  RECYCLED_UNITS                  RECYCLED_UNITS                  RECYCLED_UNITS                  RECYCLED_UNITS                  RECYCLED_UNITS                  RECYCLED_UNITS                  RECYCLED_UNITS                  RECYCLED_UNITS
# 82              Disq_and_Qual_flag              Disq_and_Qual_flag              Disq_and_Qual_flag              Disq_and_Qual_flag              Disq_and_Qual_flag              Disq_and_Qual_flag              Disq_and_Qual_flag              Disq_and_Qual_flag
# 83         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag         Land_Disq_and_Qual_flag
# 84                    TYPE_AND_USE                    TYPE_AND_USE                    TYPE_AND_USE                    TYPE_AND_USE                    TYPE_AND_USE                    TYPE_AND_USE                    TYPE_AND_USE                    TYPE_AND_USE
# 85                   PHYSICAL_CITY                   PHYSICAL_CITY                   PHYSICAL_CITY                   PHYSICAL_CITY                   PHYSICAL_CITY                   PHYSICAL_CITY                   PHYSICAL_CITY                   PHYSICAL_CITY
# 86               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE               PHYSICAL_ZIP_CODE

# %%
# spark.catalog.clearCache()
spark.stop()
