# %%
# %matplotlib -l
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# Lets try notebook instead of inline
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read a csv file. df stands for DataFrame
df = pd.read_csv('../height_weight.csv')
df
# Out:
#     sex  weight  height  repwt  repht
# 0     M      77     182   77.0  180.0
# 1     F      58     161   51.0  159.0
# 2     F      53     161   54.0  158.0
# 3     M      68     177   70.0  175.0
# 4     F      59     157   59.0  155.0
# ..   ..     ...     ...    ...    ...
# 195   M      74     175   71.0  175.0
# 196   M      83     180   80.0  180.0
# 197   M      81     175    NaN    NaN
# 198   M      90     181   91.0  178.0
# 199   M      79     177   81.0  178.0
#
# [200 rows x 5 columns]

# %%
# if emtpy shows up, restart kernel, because only one is possible to have 
df.plot()
# zoom in , zoom out, select part of the figure, expand the image etc. 
# ONLY one graph in a jupyter notebook can be interacted with at a time
# Out:
# <img src="data:image/png;base64,..." width="479">
